# %% [markdown]
# <a href="https://colab.research.google.com/github/kingajutrzenka/case-study/blob/main/Case_study_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Case study II**

# %%
import pandas as pd

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'
df_raw = pd.read_csv(url)
df_raw.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %% [markdown]
# **przygotowanie danych**

# %%
df_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df = df_raw.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...

# %%
# usuwamy niepotrzebne zmienne
del df['URL']
del df['Icon URL']
del df['Subtitle']
del df['Description']
del df['In-app Purchases']

# %%
df.head()
# Out:
#           ID           Name  Average User Rating  User Rating Count  Price  \
# 0  284921427         Sudoku                 4.00            3553.00   2.99
# 1  284926400        Reversi                 3.50             284.00   1.99
# 2  284946595        Morocco                 3.00            8376.00   0.00
# 3  285755462  Sudoku (Free)                 3.50          190394.00   0.00
# 4  285831220   Senet Deluxe                 3.50              28.00   2.99
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
# 2               Bayou Games         4+
# 3  Mighty Mighty Good Games         4+
# 4           RoGame Software         4+
#
#                                            Languages        Size  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT... 15853568.00
# 1                                                 EN 12328960.00
# 2                                                 EN   674816.00
# ...

# %%
# wykres dla kazdego indexu
df['Price'].plot()
cena = df['Price']
print(cena.std())
print(cena.mean())
print(cena.median())
print(cena.min())
print(cena.max())
# Out:
# 7.835731925029322
# 0.8134187128304777
# 0.0
# 0.0
# 179.99

# %%
df = df.set_index('ID')
df.head()
# Out:
#                     Name  Average User Rating  User Rating Count  Price  \
# ID
# 284921427         Sudoku                 4.00            3553.00   2.99
# 284926400        Reversi                 3.50             284.00   1.99
# 284946595        Morocco                 3.00            8376.00   0.00
# 285755462  Sudoku (Free)                 3.50          190394.00   0.00
# 285831220   Senet Deluxe                 3.50              28.00   2.99
#
#                           Developer Age Rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
# 284946595               Bayou Games         4+
# 285755462  Mighty Mighty Good Games         4+
# 285831220           RoGame Software         4+
#
#                                                    Languages        Size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT... 15853568.00
# 284926400                                                 EN 12328960.00
# ...

# %%
df.describe().T # tylko dla wartości numerycznych
# Out:
#                        count         mean          std      min         25%  \
# Average User Rating  7561.00         4.06         0.75     1.00        3.50
# User Rating Count    7561.00      3306.53     42322.56     5.00       12.00
# Price               16983.00         0.81         7.84     0.00        0.00
# Size                17006.00 115706429.89 203647677.85 51328.00 22950144.00
#
#                             50%          75%           max
# Average User Rating        4.50         4.50          5.00
# User Rating Count         46.00       309.00    3032734.00
# Price                      0.00         0.00        179.99
# Size                56768954.00 133027072.00 4005591040.00

# %%
df.describe(include='object').T # pokazuje teraz ograniczone statystyki dotyczące danych 'object'
# Out:
#                               count unique  \
# Name                          17007  16847
# Developer                     17007   8693
# Age Rating                    17007      4
# Languages                     16947    990
# Primary Genre                 17007     21
# Genres                        17007   1004
# Original Release Date         17007   3084
# Current Version Release Date  17007   2512
#
#                                                                      top  \
# Name                                          10-in-1 Board Games BA.net
# Developer                     Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Age Rating                                                            4+
# Languages                                                             EN
# Primary Genre                                                      Games
# Genres                                           Games, Strategy, Puzzle
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Average User Rating', 'User Rating Count', 'Price',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df.columns = [col.lower().replace(' ','_') for col in df.columns]
print(df.columns)
# dzięki temu możemy się dokopać do nazwy, wyróżniać te kolumny
# Out:
# Index(['name', 'average_user_rating', 'user_rating_count', 'price',
#        'developer', 'age_rating', 'languages', 'size', 'primary_genre',
#        'genres', 'original_release_date', 'current_version_release_date'],
#       dtype='object')

# %% [markdown]
# **analiza rozkładów**

# %%
df.primary_genre.value_counts() # zwraca ilość wystąpienia danych obiektów
# Out:
# primary_genre
# Games                16286
# Education              222
# Entertainment          198
# Utilities               77
# Sports                  60
# Reference               32
# Stickers                29
# Finance                 18
# Business                16
# Productivity            15
# Lifestyle               10
# Social Networking        9
# Book                     9
# News                     7
# Health & Fitness         5
# Food & Drink             4
# Music                    3
# Navigation               3
# Medical                  2
# Travel                   1
# Shopping                 1
# Name: count, dtype: int64

# %%
df.primary_genre.value_counts().nlargest(5)
# Out:
# primary_genre
# Games            16286
# Education          222
# Entertainment      198
# Utilities           77
# Sports              60
# Name: count, dtype: int64

# %%
list(df.primary_genre.value_counts().nlargest(5).index)
# Out:
# ['Games', 'Education', 'Entertainment', 'Utilities', 'Sports']

# %%
df.age_rating.value_counts()
# Out:
# age_rating
# 4+     11806
# 9+      2481
# 12+     2055
# 17+      665
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.set()
df.age_rating.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='age_rating'>

# %% [markdown]
# * **bar** dajemy po to, by zmienić kształt na słupki
# * seaborn aktywujemy **sns.set()**
# * **pie** dajemy po to, by zmienić kształt na koło

# %%
df.age_rating.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.price.value_counts()
# Out:
# price
# 0.00      14212
# 0.99       1078
# 1.99        515
# 2.99        471
# 4.99        237
# 3.99        163
# 9.99         88
# 11.99        59
# 5.99         42
# 6.99         32
# 179.99       30
# 7.99         17
# 8.99         13
# 19.99         9
# 14.99         4
# 12.99         3
# 16.99         2
# 29.99         2
# 99.99         1
# 139.99        1
# 37.99         1
# 36.99         1
# 18.99         1
# 59.99         1
# Name: count, dtype: int64

# %% [markdown]
# **value_counts()** zlicza wyniki

# %%
df.languages.value_counts()
# Out:
# languages
# EN                                                                12467
# EN, ZH                                                              354
# CS, NL, EN, FR, DE, IT, JA, KO, PL, PT, RU, ZH, ES, SV, ZH, TR      277
# EN, ZH, ZH                                                          248
# EN, DE                                                              147
#                                                                   ...
# NL, EN, FR, DE, ID, IT, JA, KO, PT, RU, ES, TH, TR, VI                1
# EN, IT, RU                                                            1
# ZH, EN, FR, DE, IT, JA, KO, PL, PT, RU, ZH, ES                        1
# AR, ZH, EN, FR, DE, ID, IT, JA, KO, PT, RU, ZH, ES, TH, ZH, VI        1
# ZH, EN, FR, DE, JA, KO, PL, PT, RU, ES                                1
# Name: count, Length: 990, dtype: int64

# %%
# praca z tekstem
df.languages.str.split(', ')
# dostajemy liste
# Out:
# ID
# 284921427     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 284926400                                                  [EN]
# 284946595                                                  [EN]
# 285755462     [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 285831220     [DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, R...
#                                     ...
# 1474626442                                                 [EN]
# 1474919257                                                 [EN]
# 1474962324                                                 [EN]
# 1474963671                                                 [EN]
# 1475076711                                             [EN, ZH]
# Name: languages, Length: 17007, dtype: object

# %%
df.languages.str.split(', ').str.len() # len zwraca długość listy
# Out:
# ID
# 284921427    17.00
# 284926400     1.00
# 284946595     1.00
# 285755462    17.00
# 285831220    15.00
#               ...
# 1474626442    1.00
# 1474919257    1.00
# 1474962324    1.00
# 1474963671    1.00
# 1475076711    2.00
# Name: languages, Length: 17007, dtype: float64

# %%
df['num_lang'] = df.languages.str.split(', ').str.len() #wyświetla liste dostępnych języków
df.head()
# Out:
#                     name  average_user_rating  user_rating_count  price  \
# ID
# 284921427         Sudoku                 4.00            3553.00   2.99
# 284926400        Reversi                 3.50             284.00   1.99
# 284946595        Morocco                 3.00            8376.00   0.00
# 285755462  Sudoku (Free)                 3.50          190394.00   0.00
# 285831220   Senet Deluxe                 3.50              28.00   2.99
#
#                           developer age_rating  \
# ID
# 284921427  Mighty Mighty Good Games         4+
# 284926400          Kiss The Machine         4+
# 284946595               Bayou Games         4+
# 285755462  Mighty Mighty Good Games         4+
# 285831220           RoGame Software         4+
#
#                                                    languages        size  \
# ID
# 284921427  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT... 15853568.00
# 284926400                                                 EN 12328960.00
# ...

# %%
df.num_lang.value_counts()
# Out:
# num_lang
# 1.00      12566
# 2.00       1102
# 3.00        495
# 16.00       316
# 4.00        261
# 5.00        247
# 6.00        220
# 25.00       171
# 9.00        154
# 11.00       147
# 8.00        142
# 10.00       140
# 7.00        140
# 31.00       133
# 12.00        91
# 21.00        77
# 13.00        64
# 14.00        64
# 15.00        54
# 17.00        37
# 30.00        35
# 32.00        34
# 19.00        34
# 33.00        33
# 22.00        31
# 18.00        24
# 46.00        20
# 26.00        18
# 20.00        14
# 24.00        13
# 27.00        11
# 23.00        11
# 28.00         9
# 29.00         8
# 45.00         6
# 44.00         5
# 65.00         4
# 42.00         3
# 43.00         3
# 36.00         2
# 49.00         2
# 66.00         1
# 48.00         1
# 35.00         1
# 34.00         1
# 111.00        1
# 76.00         1
# Name: count, dtype: int64

# %%
df.average_user_rating.value_counts()
# zlicza rekordy bez braków danych
# Out:
# average_user_rating
# 4.50    2861
# 4.00    1722
# 5.00     990
# 3.50     925
# 3.00     514
# 2.50     317
# 2.00     158
# 1.50      60
# 1.00      14
# Name: count, dtype: int64

# %%
df.average_user_rating.value_counts(dropna=False)
#zlicza dane + NaN
# Out:
# average_user_rating
# NaN     9446
# 4.50    2861
# 4.00    1722
# 5.00     990
# 3.50     925
# 3.00     514
# 2.50     317
# 2.00     158
# 1.50      60
# 1.00      14
# Name: count, dtype: int64

# %%
df.isnull() # zwraca wartość false dla danych i true dla NaN
# Out:
#              name  average_user_rating  user_rating_count  price  developer  \
# ID
# 284921427   False                False              False  False      False
# 284926400   False                False              False  False      False
# 284946595   False                False              False  False      False
# 285755462   False                False              False  False      False
# 285831220   False                False              False  False      False
# ...           ...                  ...                ...    ...        ...
# 1474626442  False                 True               True  False      False
# 1474919257  False                 True               True  False      False
# 1474962324  False                 True               True  False      False
# 1474963671  False                 True               True  False      False
# 1475076711  False                 True               True  False      False
#
# ...

# %%
df.isnull().sum() # zlicza brakujące dane w kazdej kategorii
# Out:
# name                               0
# average_user_rating             9446
# user_rating_count               9446
# price                             24
# developer                          0
# age_rating                         0
# languages                         60
# size                               1
# primary_genre                      0
# genres                             0
# original_release_date              0
# current_version_release_date       0
# num_lang                          60
# dtype: int64

# %%
df = df.dropna() # usuwamy puste dane
df.isnull().sum()
# Out:
# name                            0
# average_user_rating             0
# user_rating_count               0
# price                           0
# developer                       0
# age_rating                      0
# languages                       0
# size                            0
# primary_genre                   0
# genres                          0
# original_release_date           0
# current_version_release_date    0
# num_lang                        0
# dtype: int64
